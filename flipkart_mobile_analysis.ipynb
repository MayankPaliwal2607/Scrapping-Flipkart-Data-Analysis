# %%
# Importing Liabraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('flipkart_mobiles.csv')
data.head(40)
# Out:
#                                       Product Name                    RAM  \
# 0   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 1   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 2   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 3   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 4   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 5   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 6   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 7   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 8   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 9   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 10  SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 11  SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# ...

# %%
data.columns  # Printing Name of columns
# Out:
# Index(['Product Name', 'RAM', 'Display', 'Camera', 'Battery', 'Warranty',
#        'Price', 'Rating'],
#       dtype='object')

# %%
data.dtypes   # Printing Datatypes of column
# Out:
# Product Name     object
# RAM              object
# Display          object
# Camera           object
# Battery          object
# Warranty         object
# Price            object
# Rating          float64
# dtype: object

# %%
data.describe()   # Getting statistical summary of Dataframe (Excluding object datatypes)
# Out:
#            Rating
# count  522.000000
# mean     4.394253
# std      0.336011
# min      4.000000
# 25%      4.200000
# 50%      4.200000
# 75%      4.300000
# max      5.000000

# %%
data.info() # Info of Dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522 entries, 0 to 521
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  522 non-null    object
#  1   RAM           522 non-null    object
#  2   Display       522 non-null    object
#  3   Camera        522 non-null    object
#  4   Battery       522 non-null    object
#  5   Warranty      522 non-null    object
#  6   Price         522 non-null    object
#  7   Rating        522 non-null    float64
# dtypes: float64(1), object(7)
# memory usage: 32.8+ KB

# %%
# Checking Missing Data in Dataframe
missing_value = data.isnull()
missing_value.head(10)
# Out:
#    Product Name    RAM  Display  Camera  Battery  Warranty  Price  Rating
# 0         False  False    False   False    False     False  False   False
# 1         False  False    False   False    False     False  False   False
# 2         False  False    False   False    False     False  False   False
# 3         False  False    False   False    False     False  False   False
# 4         False  False    False   False    False     False  False   False
# 5         False  False    False   False    False     False  False   False
# 6         False  False    False   False    False     False  False   False
# 7         False  False    False   False    False     False  False   False
# 8         False  False    False   False    False     False  False   False
# 9         False  False    False   False    False     False  False   False

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(data['Rating'], color='g')
# Set x/y Labels
plt.pyplot.xlabel('Rating')
plt.pyplot.ylabel('Count')
plt.pyplot.title('Rating Bins')
# Out:
# Text(0.5, 1.0, 'Rating Bins')

# %%
data.head(45)
# Out:
#                                       Product Name                    RAM  \
# 0   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 1   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 2   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 3   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 4   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 5   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 6   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 7   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 8   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 9   SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 10  SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# 11  SAMSUNG Galaxy A71 (Prism Crush Black, 128 GB)  4 GB RAM | 128 GB ROM
# ...
